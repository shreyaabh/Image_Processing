# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
import tensorflow as tf

# %%
from tensorflow.keras.preprocessing.image import load_img, img_to_array

# %%
# load model
model = tf.keras.models.load_model('object_detection.h5')
print('model loaded sucessfully')
# Out:
# model loaded sucessfully

# %%
path = './images/N207.jpeg'
image = load_img(path) # PIL object
image = np.array(image,dtype=np.uint8) # 8 bit array (0,255)
image1 = load_img(path,target_size=(224,224))
image_arr_224 = img_to_array(image1)/255.0  # convert into array and get the normalized output

# %%
# size of the orginal image
h,w,d = image.shape
print('Height of the image =',h)
print('Width of the image =',w)
# Out:
# Height of the image = 423
# Width of the image = 541

# %%
plt.figure(figsize=(10,8))
plt.imshow(image)
plt.show()

# %%
image_arr_224.shape
# Out:
# (224, 224, 3)

# %%
test_arr = image_arr_224.reshape(1,224,224,3)
test_arr.shape
# Out:
# (1, 224, 224, 3)

# %%
# make predictions
coords = model.predict(test_arr)
coords
# Out:
# array([[2.6192056e-16, 1.0000000e+00, 6.9385195e-01, 1.0000000e+00]],
#       dtype=float32)

# %%
# denormalize the values
denorm = np.array([w,w,h,h])
coords = coords * denorm
coords
# Out:
# array([[1.41699023e-13, 5.41000000e+02, 2.93499374e+02, 4.23000000e+02]])

# %%
coords = coords.astype(np.int32)
coords
# Out:
# array([[  0, 541, 293, 423]])

# %%
# draw bounding on top the image
xmin, xmax,ymin,ymax = coords[0]
pt1 =(xmin,ymin)
pt2 =(xmax,ymax)
print(pt1, pt2)
cv2.rectangle(image,pt1,pt2,(0,255,0),3)

plt.figure(figsize=(10,8))
plt.imshow(image)
plt.show()
# Out:
# (0, 293) (541, 423)

# %%
# create pipeline
path = './test_images/N207.jpeg'
def object_detection(path):
    # read image
    image = load_img(path) # PIL object
    image = np.array(image,dtype=np.uint8) # 8 bit array (0,255)
    image1 = load_img(path,target_size=(224,224))
    # data preprocessing
    image_arr_224 = img_to_array(image1)/255.0  # convert into array and get the normalized output
    h,w,d = image.shape
    test_arr = image_arr_224.reshape(1,224,224,3)
    # make predictions
    coords = model.predict(test_arr)
    # denormalize the values
    denorm = np.array([w,w,h,h])
    coords = coords * denorm
    coords = coords.astype(np.int32)
    # draw bounding on top the image
    xmin, xmax,ymin,ymax = coords[0]
    pt1 =(xmin,ymin)
    pt2 =(xmax,ymax)
    print(pt1, pt2)
    cv2.rectangle(image,pt1,pt2,(0,255,0),3)
    return image, coords

# %%
path = './images/N147.jpeg'
image, cods = object_detection(path)

plt.figure(figsize=(10,8))
plt.imshow(image)
plt.show()
# Out:
# (0, 581) (1070, 907)

# %%
import pytesseract as pt

# %%
path = './images/N207.jpeg'
image, cods = object_detection(path)

plt.figure(figsize=(10,8))
plt.imshow(image)
plt.show()
# Out:
# (0, 293) (541, 423)

# %%
img = np.array(load_img(path))
xmin ,xmax,ymin,ymax = cods[0]
roi = img[ymin:ymax,xmin:xmax]

# %%
plt.imshow(roi)
plt.show()

# %%
# extract text from image
text = pt.image_to_string(roi)
print(text)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# c:\users\hp\appdata\local\programs\python\python39\lib\site-packages\pytesseract\pytesseract.py in run_tesseract(input_filename, output_filename_base, extension, lang, config, nice, timeout)
#     251     try:
# --> 252         proc = subprocess.Popen(cmd_args, **subprocess_args())
#     253     except OSError as e:
#
# c:\users\hp\appdata\local\programs\python\python39\lib\subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, user, group, extra_groups, encoding, errors, text, umask)
#     950
# --> 951             self._execute_child(args, executable, preexec_fn, close_fds,
#     952                                 pass_fds, cwd, env,
#
# c:\users\hp\appdata\local\programs\python\python39\lib\subprocess.py in _execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, unused_restore_signals, unused_gid, unused_gids, unused_uid, unused_umask, unused_start_new_session)
#    1419             try:
# -> 1420                 hp, ht, pid, tid = _winapi.CreateProcess(executable, args,
#    1421                                          # no special security
#
# FileNotFoundError: [WinError 2] The system cannot find the file specified
#
# During handling of the above exception, another exception occurred:
#
# TesseractNotFoundError                    Traceback (most recent call last)
# <ipython-input-22-cff204bc14e6> in <module>
#       1 # extract text from image
# ----> 2 text = pt.image_to_string(roi)
#       3 print(text)
#
# c:\users\hp\appdata\local\programs\python\python39\lib\site-packages\pytesseract\pytesseract.py in image_to_string(image, lang, config, nice, output_type, timeout)
#     411     args = [image, 'txt', lang, config, nice, timeout]
#     412
# --> 413     return {
#     414         Output.BYTES: lambda: run_and_get_output(*(args + [True])),
#     415         Output.DICT: lambda: {'text': run_and_get_output(*args)},
#
# c:\users\hp\appdata\local\programs\python\python39\lib\site-packages\pytesseract\pytesseract.py in <lambda>()
#     414         Output.BYTES: lambda: run_and_get_output(*(args + [True])),
#     415         Output.DICT: lambda: {'text': run_and_get_output(*args)},
# --> 416         Output.STRING: lambda: run_and_get_output(*args),
#     417     }[output_type]()
#     418
#
# c:\users\hp\appdata\local\programs\python\python39\lib\site-packages\pytesseract\pytesseract.py in run_and_get_output(image, extension, lang, config, nice, timeout, return_bytes)
#     282         }
#     283
# --> 284         run_tesseract(**kwargs)
#     285         filename = kwargs['output_filename_base'] + extsep + extension
#     286         with open(filename, 'rb') as output_file:
#
# c:\users\hp\appdata\local\programs\python\python39\lib\site-packages\pytesseract\pytesseract.py in run_tesseract(input_filename, output_filename_base, extension, lang, config, nice, timeout)
#     254         if e.errno != ENOENT:
#     255             raise e
# --> 256         raise TesseractNotFoundError()
#     257
#     258     with timeout_manager(proc, timeout) as error_string:
#
# TesseractNotFoundError: tesseract is not installed or it's not in your PATH. See README file for more information.
